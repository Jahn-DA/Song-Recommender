# %%
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
import requests

# %%
nothot100 = pd.read_csv("/Users/jxhn/Downloads/Spotify_final_dataset.csv")

# %%
nothot100
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# ...

# %%
nothot100.sample(2500)
# Out:
#       Position    Artist Name                               Song Name  Days  \
# 9880      9881         Latto                                  Wheelie     1
# 6589      6590   David Bowie   Life On Mars?  1999 Remastered Version     4
# 64          65  James Arthur                     Say You Won't Let Go  1083
# 4832      4833        Halsey                                      3am     7
# 6389      6390            RM                              Wild Flower     3
# ...        ...            ...                                     ...   ...
# 3520      3521          Lauv                        Modern Loneliness    21
# 2695      2696         Quavo                                 PASS OUT    23
# 1525      1526  Rae Sremmurd                             Throw Sum Mo   246
# 9893      9894  Chan Se Park                           Thinkin of You     1
# 4190      4191  Taylor Swift           Hey Stephen (Taylor’s Version)     7
#
# ...

# %%
nothot100 = nothot100[["Artist Name","Song Name"]]

# %%
nothot100
# Out:
#               Artist Name                                   Song Name
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
# [11084 rows x 2 columns]

# %%
hot100 = pd.read_csv("/Users/jxhn/Desktop/IRONHACK/Week_6/Day_1/Morning/lab-web-scraping-single-page/hot100.csv")

# %%
hot100
# Out:
#                                                Artist  \
# 0                           Jung Kook Featuring Latto
# 1                                        Jason Aldean
# 2                                       Morgan Wallen
# 3                                          Luke Combs
# 4                                 Rema & Selena Gomez
# ..                                                ...
# 95                     Rylo Rodriguez Featuring NoCap
# 96                 That Mexican OT, Paul Wall & DRODi
# 97  Metro Boomin, Swae Lee & NAV Featuring A Boogi...
# 98                 Lil Uzi Vert Featuring Nicki Minaj
# 99                                           Parmalee
#
#                        Title
# 0                      Seven
# 1   Try That In A Small Town
# 2                 Last Night
# 3                   Fast Car
# 4                  Calm Down
# ..                       ...
# 95             Thang For You
# 96               Johnny Dang
# 97                   Calling
# ...

# %%
nothot100 = nothot100.sample(2500)

# %%
nothot100 = nothot100.rename(columns={'Artist Name': 'Artist', 'Song Name': 'Title'})

# %%
concatenated_df = pd.concat([hot100, nothot100]).drop_duplicates()

# %%
concatenated_df
# Out:
#                           Artist                     Title
# 0      Jung Kook Featuring Latto                     Seven
# 1                   Jason Aldean  Try That In A Small Town
# 2                  Morgan Wallen                Last Night
# 3                     Luke Combs                  Fast Car
# 4            Rema & Selena Gomez                 Calm Down
# ...                          ...                       ...
# 132                  Bruno Mars         That's What I Like
# 8902             Eslabon Armado           Ando Más Que Mal
# 10609                Tory Lanez              All The Girls
# 3674                   Flo Rida                 Dirty Mind
# 1595                  Bad Bunny                 Ignorantes
#
# [2595 rows x 2 columns]

# %%
concatenated_df = concatenated_df.reset_index(drop=True)

# %%
concatenated_df
# Out:
#                          Artist                     Title
# 0     Jung Kook Featuring Latto                     Seven
# 1                  Jason Aldean  Try That In A Small Town
# 2                 Morgan Wallen                Last Night
# 3                    Luke Combs                  Fast Car
# 4           Rema & Selena Gomez                 Calm Down
# ...                         ...                       ...
# 2590                Bruno Mars         That's What I Like
# 2591            Eslabon Armado           Ando Más Que Mal
# 2592                Tory Lanez              All The Girls
# 2593                  Flo Rida                 Dirty Mind
# 2594                 Bad Bunny                 Ignorantes
#
# [2595 rows x 2 columns]

# %%
concatenated_df.to_csv('nothot100.csv', index=False)
